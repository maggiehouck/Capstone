# %%
import os
import PyPDF2 as pypdf
#import pdfminer
import pandas as pd
import re
import time
from ipynb.fs.full.Trafficking_Ranking import get_trafficking_ratings

data_dir = './data'

# %%
#list to get police departments 
pd_list = ['police department', 'p.d.', 'pd', 'agency', 'law enforcement agency', 'sheriff department', 'highway patrol']
abrev_pd_list = ['federal bureau of investigations', 'fbi', 'dhs', 'f.b.i', 'd.h.s']

# %%
def get_court(text):
    return text.split("\n")[1]

# takes the text of a court case pdf and returns which court heard the case
def get_arresting_dept(text):
    matches = []

    for word in pd_list:
        #pattern that gets the two words before "police department" or whatever other word we look for
        pattern = r'(\b\w+\b)\s+(\b\w+\b)\s+' + word

        match_list = re.findall(pattern, text)

        # print the matches
        for match in match_list:
            combo = match[0] + ' ' + match[1] + ' ' + word
            matches.append(combo)

    word_dict = {}
    for word in abrev_pd_list: 
        word_count = text.count(word)
        word_dict[word] = word_count

    word_dict = {x:y for x,y in word_dict.items() if y!=0}

    #count number of each occurence 
    counts = {}
    for i in matches:
        counts[i] = counts.get(i, 0) + 1

    counts = counts | word_dict

    #sort the dictionary by value 
    counts = {k: v for k, v in sorted(counts.items(), key=lambda item: item[1], reverse=True)}
    return counts

def get_courtcode(text, code):
    if code in text:
        return 'YES'
    else:
        return 'NO'

def get_defendant_name(text):
    try:
        defs = text.split("reporter\n")[1].split('defendant')[0]
        ind = defs.count("plaintiff")
        defs = defs.split("plaintiff")[ind]

        defs = defs.replace("\n", "")
        if 'v.' in defs:
            defs = defs.split("v.")[1].split('defendant')[0].strip()[:-1]
        elif 'vs' in defs:
            defs = defs.split("vs.")[1].split('defendant')[0].strip()[:-1]

        elif 'respondent-appellant' in defs:
            defs = defs.split("vs.")[1].split('respondent')[0].strip()[:-1]

            #defs_final = defs
        return defs
    except:
        return None
        
    #return defs_final

def get_traffic_count(text, word_list):
    word_dict = {}
    for word in word_list: 
        word_count = text.count(word)
        word_dict[word] = word_count
    return word_dict


def get_traffic_appearance(text, word_list):
    word_dict = {}
    for word in word_list: 
        if word in text:
            word_dict[word] = 1
        else:
            word_dict[word] = 0
    return word_dict

# %%
matches = []
text = 'the new york police department does not like the fbi or the f.b.i.'
for word in pd_list:
    #pattern that gets the two words before "police department" or whatever other word we look for
    pattern = r'(\b\w+\b)\s+(\b\w+\b)\s+' + word

    match_list = re.findall(pattern, text)

    # print the matches
    for match in match_list:
        combo = match[0] + ' ' + match[1] + ' ' + word
        matches.append(combo)
'''

for word in abrev_pd_list:
    match_list2 = re.findall(word, text)

    for match in match_list2:
        matches.append(match)
'''

word_dict = {}
for word in abrev_pd_list: 
    word_count = text.count(word)
    word_dict[word] = word_count

word_dict = {x:y for x,y in word_dict.items() if y!=0}

#count number of each occurence 
counts = {}
for i in matches:
    counts[i] = counts.get(i, 0) + 1

counts = counts | word_dict

#sort the dictionary by value 
counts = {k: v for k, v in sorted(counts.items(), key=lambda item: item[1], reverse=True)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 34
#      31 for i in matches:
#      32     counts[i] = counts.get(i, 0) + 1
# ---> 34 counts = counts | word_dict
#      36 #sort the dictionary by value
#      37 counts = {k: v for k, v in sorted(counts.items(), key=lambda item: item[1], reverse=True)}
#
# TypeError: unsupported operand type(s) for |: 'dict' and 'dict'

# %%
def get_traffic_count(text, word_list):
    word_dict = {}
    for word in word_list: 
        word_count = text.count(word)
        word_dict[word] = word_count
    return word_dict


def get_traffic_appearance(text, word_list):
    word_dict = {}
    for word in word_list: 
        if word in text:
            word_dict[word] = 1
        else:
            word_dict[word] = 0
    return word_dict

# %%
st = time.time()

files = []
defendant = []
court = []
c1591 = []
c2421 = []
c1594 = []
c2422 = []
c2423 = []
c1328 = []
c1952 = []
c1581 = []
c1584 = []
c1589 = []
c1590 = []
c1592 = []
sex_trafficking_score = []
labor_trafficking_score = []
pdept = []

for filename in os.scandir(data_dir):
        if (".pdf" in filename.name) and ("Attachment" not in filename.name) and ():
            reader = pypdf.PdfReader(filename.path)
            pypdf2_text = ""
            for i in range(len(reader.pages)):
                pypdf2_text += reader.pages[i].extract_text()  
            pypdf2_text = pypdf2_text.lower()
            print(filename.name)
            files.append(filename.name)
            court.append(get_court(pypdf2_text))
            defendant.append(get_defendant_name(pypdf2_text))
            #pdept.append(get_arresting_dept(pypdf2_text))
            c1591.append(get_courtcode(pypdf2_text, "§ 1591"))
            c2421.append(get_courtcode(pypdf2_text, "§ 2421"))
            c1594.append(get_courtcode(pypdf2_text, "§ 1594"))
            c2422.append(get_courtcode(pypdf2_text, "§ 2422"))
            c2423.append(get_courtcode(pypdf2_text, "§ 2423"))
            c1328.append(get_courtcode(pypdf2_text, "§ 1328"))
            c1952.append(get_courtcode(pypdf2_text, "§ 1952"))
            c1581.append(get_courtcode(pypdf2_text, "§ 1581"))
            c1584.append(get_courtcode(pypdf2_text, "§ 1584"))
            c1589.append(get_courtcode(pypdf2_text, "§ 1589"))
            c1590.append(get_courtcode(pypdf2_text, "§ 1590"))
            c1592.append(get_courtcode(pypdf2_text, "§ 1592"))
            sex_traffic_score, labor_traffic_score = get_trafficking_ratings(pypdf2_text)
            sex_trafficking_score.append(sex_traffic_score)
            labor_trafficking_score.append(labor_traffic_score)
            print(get_trafficking_ratings(pypdf2_text))
        else:
            continue
            
et = time.time()            
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
# Out:
# Dahlia v. Rodriguez, 735 F.3d 1060.pdf
# (10.391304347826088, 9.5)
# Doe v. Kerry, 2016 U.S. Dist. LEXIS 130788.pdf
# (11.318260869565217, 10.654545454545453)
# Doe v. State of California, 8 Cal. App. 5th 832.pdf
# (9.709565217391305, 8.5)
# Doe v. Twitter, Inc., 555 F. Supp. 3d 889.pdf
# (15.231469979296065, 11.031818181818183)
# Dream Palace v. County of Maricopa, 384 F.3d 990.pdf
# (10.715942028985506, 9.75)
# Droegemeier v. Barr, 446 F. Supp. 3d 671.pdf
# (10.339130434782609, 10.127272727272729)
# Duncan v. Becerra, 366 F. Supp. 3d 1131.pdf
# (11.72472049689441, 10.0)
# Fletcher v. Lizarraga, 2017 U.S. Dist. LEXIS 102386.pdf
# (11.32463768115942, 9.5)
# Wattson v. Altabateshospital.com, 2014 U.S. Dist. LEXIS 70776.pdf
# (9.233043478260868, 9.863636363636363)
# Winn v. Sec'y of Corr., 2018 U.S. Dist. LEXIS 152322.pdf
# (12.351304347826087, 9.5)
# Wright v. Superior Court, 15 Cal. 4th 521.pdf
# (9.754782608695653, 10.0)
# Zayas v. Ortega, 2018 U.S. Dist. LEXIS 241393.pdf
# (10.771014492753622, 9.25)
# Execution time: 157.0632140636444 seconds

# %%
cases = pd.DataFrame({'file_name': files,
                      'Court': court,
                      'Defendant(s)': defendant,
                      #'Arresting PD(s)': pdept,
                      'Sex_Traffic_Score':sex_trafficking_score,
                      'Labor_Traffic_Score': labor_trafficking_score,
                      'Code_1591': c1591,
                      'Code_2421': c2421, 
                      'Code_1594': c1594, 
                      'Code_2422': c2422, 
                      'Code_2423': c2423, 
                      'Code_1328': c1328, 
                      'Code_1952': c1952,
                      'Code_1581': c1581,
                      'Code_1584': c1584,
                      'Code_1589': c1589,
                      'Code_1590': c1590,
                      'Code_1592': c1592})
cases = cases.sort_values(by="Sex_Traffic_Score", ascending=False)

# %%
cases.head(50)
# Out:
#                                              file_name  \
# 94            United States v. Tavares, 705 F.3d 4.pdf
# 22          United States v. Houston, 857 F.3d 427.pdf
# 98   United States v. Daniels, 435 F. Supp. 3d 214.pdf
# 106                Ricchio v. McLean, 853 F.3d 553.pdf
# 7             United States v. Graham, 976 F.3d 59.pdf
# 111           United States v. Davis, 923 F.3d 228.pdf
# 78    United States v. Reiner, 397 F. Supp. 2d 101.pdf
# 61   United States v. Henry, 2014 U.S. Dist. LEXIS ...
# 110  United States v. Abraham, 2023 U.S. App. LEXIS...
# 4           United States v. Sabatino, 943 F.2d 94.pdf
# 109  United States v. Raymond, 700 F. Supp. 2d 142.pdf
# 88             United States v. Dyer, 589 F.3d 520.pdf
# 9    Reiner v. United States, 2010 U.S. Dist. LEXIS...
# 41    United States v. Reiner, 382 F. Supp. 2d 195.pdf
# 104  United States v. Abraham, 498 F. Supp. 3d 175.pdf
# 42           United States v. Raymond, 697 F.3d 32.pdf
# 103  Wadsworth v. Me. Sch. Admin. Dist. 40, 2023 U....
# 6          United States v. Vel_zquez, 777 F.3d 91.pdf
# 38   Hornof v. Waller, 2020 U.S. Dist. LEXIS 198578...
# 64         United States v. Roy, 114 F. Supp. 2d 1.pdf
# 87             Bodman v. Maine, 787 F. Supp. 2d 89.pdf
# 72   Fenton v. United States, 2009 U.S. Dist. LEXIS...
# 15   United States v. Cameron, 2011 U.S. Dist. LEXI...
# 66          United States v. Saemisch, 18 F.4th 50.pdf
# 83                    Eves v. LePage, 927 F.3d 575.pdf
# 84            United States v. Hilton, 167 F.3d 61.pdf
# 59    Doe v. Magnusson, 2005 U.S. Dist. LEXIS 6143.pdf
# 100  United States v. Miranda, 2019 U.S. Dist. LEXI...
# 40              United States v. Diaz, 597 F.3d 56.pdf
# 74             United States v. Henry, 827 F.3d 16.pdf
# 0     United States v. Bailey, 377 F. Supp. 2d 268.pdf
# 61                                          paul henry
# 110                                   reginald abraham
# 4                                       diane sabatino
# 109             (callaghan) 296united states of americ
# 88                                     mark david dyer
# 9    united states of america, respondentprior hist...
# 41   gary h. reiner; kittery health club d/b/a dani...
# 104                                   reginald abraham
# 42   (callaghan) 866; 2012 wl 4801323united states ...
# 103  maine school administrative district 40/region...
# 6                                    josé l. velázquez
# 38                                shane waller, et al.
# 64                                           billy roy
# 87   state of maine, department of health and human...
# 72                 , pro se, terre haute, in.for usa,
# 15   james m. cameronsubsequent history: motion den...
# 66                                christopher saemisch
# 83                                      paul r. lepage
# 84                                        david hilton
# 59                            martin magnusson, et. al
# 100                                       jose miranda
# 40   (callaghan) 728united states of america, appellee
# 74                                paul henry, a/k/a lt
# 0                                        gerald bailey
# 51   (callaghan) 885united states of america, appellee
# 44   bijal, inc. d/b/a shangri-la motel; ashvinkuma...
# 28   john balsamo, a/k/a john russo, et al.core ter...
# 1                                           byron polk
# 65                                          byron polk
# 12                                    joseph pelletier
# 77   g. steven rowe, in his official capacity as at...
# 81   : joel b. casey, lead attorney, office of the ...
# 45                     the mcshane group, inc., et al.
# 67                                      steven webster
# 89   alan ketchensubsequent history: affirmed by un...
# 52   susan pozzy, appelleesubsequent history:  [**1...
# 86                          town of pittsfield, et al.
# 34   malcolm greenlawsubsequent history: motion dis...
# 3    michael chertoff, secretary of the united stat...
# 35             erick levar adams, a/k/a x, a/k/a deuce
# 14                                        david hilton
# 82   rayevon deschambaultsubsequent history: dismis...
# 33             maine department of corrections, et al.
#
#                                        Arresting PD(s)  Sex_Traffic_Score  \
# 94                                          {'fbi': 3}          16.100787
# 22                                          {'fbi': 1}          14.699379
# 98                                                  {}          13.926294
# 106                                                 {}          13.925549
# 7                                                   {}          13.628157
# 111                                                 {}          13.304099
# 78                                                  {}          13.185839
# 61   {'the portland police department': 5, 'fbi': 3...          13.033789
# 110                                   {'in a p.d.': 1}          12.855818
# 4                                           {'fbi': 1}          12.804224
# 109  {'fbi': 4, 'lack of p.d.': 1, 'expert on p.d.'...          12.804224
# 88   {'fbi': 3, 'ultra hard p.d.': 1, 'child porn p...          12.528282
# 9    {'fbi': 3, 'the kittery police department': 2,...          12.252919
# 41                                          {'fbi': 5}          12.145093
# 104                                 {'in the p.d.': 1}          11.665176
# 42                                                  {}          11.608861
# 103  {'the governmental agency': 4, 'the waldoboro ...          11.310807
# 6                                                   {}          11.292919
# 38   {'environmental protection agency': 4, 'a fede...          11.260870
# 64                                                  {}          11.239586
# 87                          {'agreement or agency': 1}          11.155942
# 72               {'the portland police department': 2}          11.101449
# 15                             {'child abuse p.d.': 1}          11.043478
# 66                             {'a diagnosed p.d.': 1}          11.043478
# 83   {'the discharging agency': 2, 'director of age...          11.043478
# 84   {'molesters and p.d.': 1, 'used by p.d.': 1, '...          10.973913
# 59   {'that the police department': 1, 'entered the...          10.881159
# 100                                                 {}          10.826087
# 40       {'fbi': 2, 'the boston police department': 1}          10.824348
# 74   {'the portland police department': 1, 'drug en...          10.771014
# 0                                           {'fbi': 1}          10.757847
# 51                                                  {}          10.715942
# 44                                                  {}          10.608696
# 28   {'the portland police department': 3, 'been fo...          10.554783
# 1                                                   {}          10.500870
# 65                                                  {}          10.500870
# 12   {'the topsham police department': 1, 'drug enf...          10.446957
# 77                      {'federal aviation agency': 2}          10.444058
# 81   {'drug enforcement agency': 1, 'locating an ag...          10.444058
# 45                                                  {}          10.391304
# 67   {'called the police department': 1, 'of the po...          10.391304
# 89   {'by brewer police department': 2, 'point of p...          10.380290
# 52                                                  {}          10.339130
# 86   {'the pittsfield police department': 10, 'the ...          10.338551
# 34             {'for luis p.d.': 1, 'by luis p.d.': 1}          10.338551
# 3    {'deslauriers and p.d.': 16, 'dhs': 13, 'and a...          10.338551
# 35   {'drug enforcement agency': 1, 'law enforcemen...          10.285797
# 14   {'fbi': 15, 'law enforcement agency': 4, 'to a...          10.285797
# 82   {'drug enforcement agency': 3, 'fbi': 3, 'cont...          10.277101
# 33                                                  {}          10.277101
#
#      Labor_Traffic_Score Code_1591 Code_2421 Code_1594 Code_2422 Code_2423  \
# 94              9.250000       YES       YES        NO        NO       YES
# 22             10.127273        NO       YES        NO       YES        NO
# 98              9.750000        NO       YES        NO       YES       YES
# 106            13.863636       YES        NO       YES        NO        NO
# 7               9.000000       YES       YES        NO        NO        NO
# 111             9.250000       YES       YES        NO        NO        NO
# 78              9.500000        NO        NO        NO       YES        NO
# 61              9.500000       YES        NO        NO        NO        NO
# 110             9.000000       YES        NO        NO        NO        NO
# 4              10.000000        NO       YES        NO        NO        NO
# 109             9.750000        NO        NO        NO        NO       YES
# 88              9.500000        NO        NO        NO        NO        NO
# 9               9.750000        NO        NO        NO        NO        NO
# 41              9.750000        NO        NO        NO        NO        NO
# 104             9.000000        NO        NO        NO        NO        NO
# 42              8.500000        NO        NO        NO        NO       YES
# 103             9.750000        NO        NO        NO        NO        NO
# 6               8.500000        NO        NO        NO        NO       YES
# 38             22.445455        NO        NO        NO        NO        NO
# 64              8.500000        NO       YES        NO        NO        NO
# 87              9.250000        NO        NO        NO        NO        NO
# 72              9.750000        NO        NO        NO        NO        NO
# 15              9.500000        NO        NO        NO        NO        NO
# 66              9.750000        NO        NO        NO        NO        NO
# 83             10.390909        NO        NO        NO        NO        NO
# 84              9.000000        NO        NO        NO        NO        NO
# 59              9.500000        NO        NO        NO        NO        NO
# 100             9.500000        NO        NO        NO        NO        NO
# 40              9.500000        NO        NO        NO        NO        NO
# 74              9.750000        NO        NO        NO        NO        NO
# 0               8.750000        NO        NO        NO       YES        NO
# 51              9.250000        NO        NO        NO        NO        NO
# 44             11.250000        NO        NO        NO        NO        NO
# 28              9.750000        NO        NO        NO        NO        NO
# 1               9.750000        NO        NO        NO        NO        NO
# 65              9.750000        NO        NO        NO        NO        NO
# 12              9.000000        NO        NO        NO        NO        NO
# 77              9.750000        NO        NO        NO        NO        NO
# 81             10.500000        NO        NO        NO        NO        NO
# 45             10.750000        NO        NO        NO        NO        NO
# 67              9.250000        NO        NO        NO        NO        NO
